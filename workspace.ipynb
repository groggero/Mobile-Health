# %%
# INTERACTIVE PLOTS (only if you code locally, unfortunately)
# This cell can take some minutes to run
# You should only need to run this cell once and not everytime you open the script
# In case the plotting of the data below does not work because of the error "Error displaying widget: model not found"
# you'll probably have to restart your kernel once more.

# IMPORTANT: After running this cell, restart your kernel
# uncomment the next two lines for interactive plots
#!jupyter labextension install @jupyter-widgets/jupyterlab-manager jupyter-leaflet
#!pip install nodejs

# %%
import matplotlib.pyplot as plt

# You may change the mhealth_activity module but your algorithm must support the original version
from mhealth_activity import Recording, Trace, Activity, WatchLocation, Path

# For interactive plots, uncomment the following line
# %matplotlib widget

# %% [markdown]
# # Reading sensor data from PKL file
#
# Create an instance of the <code>Recording</code> class that manages the data from a file

# %%
#recording = Recording('/kaggle/input/competitions/26-mham-ex3/data/train/train_trace_013.pkl')
#recording = Recording('data/train/train_trace_013.pkl')
recording= Recording('/Users/giaco/Desktop/ETH/Mobile_Health/DATA/data/train/train_trace_012.pkl') # for Giacomo

# The data is stored inside a dictionary (access: recording.data["key"])
print("\r\nAvailable data traces:")
print(list(recording.data.keys()))

if not(recording.labels is None):
    print("\r\nLabels: ")
    print(recording.labels)

print(f"\r\nRecording:")
for key in list(recording.data.keys()):
    print(f'{key}: {recording.data[key]}')
# Out:
# Available data traces:
# ['phone_mx', 'gx', 'altitude', 'phone_rotx', 'phone_gravy', 'phone_gz', 'phone_my', 'timestamp', 'gz', 'ax', 'my', 'phone_pressure', 'phone_gravx', 'phone_gy', 'phone_orientationx', 'temperature', 'phone_az', 'mz', 'az', 'gy', 'phone_mz', 'phone_light', 'phone_rotm', 'phone_ax', 'packetNumber', 'phone_orientationz', 'phone_gravz', 'phone_gx', 'phone_lax', 'phone_laz', 'phone_rotz', 'ay', 'phone_roty', 'phone_lay', 'mx', 'phone_ay', 'phone_orientationy']
#
# Labels:
# {'path_idx': 3, 'watch_loc': 0, 'step_count': -1, 'activities': {'standing': True, 'walking': True, 'running': True, 'cycling': True}}
#
# Recording:
# phone_mx: Trace(title='phone_mx', total_time=579.33, samplerate=90.78, max_update_gap=53.52)
# gx: Trace(title='gx', total_time=579.33, samplerate=200.07, max_update_gap=0.58)
# altitude: Trace(title='altitude', total_time=579.33, samplerate=12.50, max_update_gap=101.94)
# phone_rotx: Trace(title='phone_rotx', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# phone_gravy: Trace(title='phone_gravy', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# phone_gz: Trace(title='phone_gz', total_time=579.33, samplerate=382.08, max_update_gap=35.68)
# phone_my: Trace(title='phone_my', total_time=579.33, samplerate=90.78, max_update_gap=53.52)
# timestamp: Trace(title='timestamp', total_time=579.33, samplerate=12.50, max_update_gap=9.31)
# gz: Trace(title='gz', total_time=579.33, samplerate=200.07, max_update_gap=0.58)
# ax: Trace(title='ax', total_time=579.33, samplerate=200.07, max_update_gap=0.58)
# my: Trace(title='my', total_time=579.33, samplerate=12.50, max_update_gap=9.78)
# phone_pressure: Trace(title='phone_pressure', total_time=579.33, samplerate=22.69, max_update_gap=26.91)
# phone_gravx: Trace(title='phone_gravx', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# phone_gy: Trace(title='phone_gy', total_time=579.33, samplerate=382.08, max_update_gap=17.84)
# phone_orientationx: Trace(title='phone_orientationx', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# temperature: Trace(title='temperature', total_time=579.33, samplerate=12.50, max_update_gap=225.30)
# phone_az: Trace(title='phone_az', total_time=579.33, samplerate=382.10, max_update_gap=17.84)
# mz: Trace(title='mz', total_time=579.33, samplerate=12.50, max_update_gap=9.78)
# az: Trace(title='az', total_time=579.33, samplerate=200.07, max_update_gap=1.16)
# gy: Trace(title='gy', total_time=579.33, samplerate=200.07, max_update_gap=0.58)
# phone_mz: Trace(title='phone_mz', total_time=579.33, samplerate=90.78, max_update_gap=53.52)
# phone_light: Trace(title='phone_light', total_time=579.33, samplerate=6.26, max_update_gap=53.73)
# phone_rotm: Trace(title='phone_rotm', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# phone_ax: Trace(title='phone_ax', total_time=579.33, samplerate=382.10, max_update_gap=17.84)
# packetNumber: Trace(title='packetNumber', total_time=579.33, samplerate=12.50, max_update_gap=9.31)
# phone_orientationz: Trace(title='phone_orientationz', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# phone_gravz: Trace(title='phone_gravz', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# phone_gx: Trace(title='phone_gx', total_time=579.33, samplerate=382.08, max_update_gap=35.69)
# phone_lax: Trace(title='phone_lax', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# phone_laz: Trace(title='phone_laz', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# phone_rotz: Trace(title='phone_rotz', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# ay: Trace(title='ay', total_time=579.33, samplerate=200.07, max_update_gap=0.58)
# phone_roty: Trace(title='phone_roty', total_time=579.33, samplerate=191.02, max_update_gap=26.76)
# phone_lay: Trace(title='phone_lay', total_time=579.33, samplerate=191.03, max_update_gap=53.52)
# mx: Trace(title='mx', total_time=579.33, samplerate=12.50, max_update_gap=9.78)
# phone_ay: Trace(title='phone_ay', total_time=579.33, samplerate=382.10, max_update_gap=17.84)
# phone_orientationy: Trace(title='phone_orientationy', total_time=579.33, samplerate=191.02, max_update_gap=26.76)

# %%
print("ACTIVITIES")
for activity in Activity:
    if activity.value in recording.labels["activities"]:
        print(f"{activity.name} is contained in the recording, thus '{activity.name.lower()}': True")
    else:
        print(f"{activity.name} is NOT contained in the recording, thus '{activity.name.lower()}': False")

print("\r\nWATCH LOCATION")
print(f"The LilyGo was worn on the {WatchLocation(recording.labels['watch_loc']).name.lower()}.")

print("\r\nPATH IDX")
print(f"The participant completed {Path(recording.labels['path_idx']).name.lower()}.")

print("\r\nSTEP COUNT")
if "step_count" in recording.labels:
    if recording.labels["step_count"] != -1:
        print(f"The participant performed {recording.labels['step_count']} steps.")
    else:
        print("The step count is not available.")
else:
    print("The step count is not available.")
# Out:
# ACTIVITIES
# STANDING is contained in the recording, thus 'standing': True
# WALKING is contained in the recording, thus 'walking': True
# RUNNING is NOT contained in the recording, thus 'running': False
# CYCLING is NOT contained in the recording, thus 'cycling': False
#
# WATCH LOCATION
# The LilyGo was worn on the belt.
#
# PATH IDX
# The participant completed path_2.
#
# STEP COUNT
# The participant performed None steps.

# %% [markdown]
# ## Working with timeseries
# Every value in this dictionary holds a <code>Trace</code> object to manage the data from one sensor

# %%
#recording = Recording('/kaggle/input/competitions/26-mham-ex3/data/example/medium_walk.pkl')  # Second example file: data/example/short_walk.pkl
#recording = Recording('/Users/theoheim/Desktop/ETH/MA2/MobileHealth/Exercise3/26-mham-ex3/data/example/short_walk.pkl') #for Theo
recording = Recording('/Users/giaco/Desktop/ETH/Mobile_Health/DATA/data/example/short_walk.pkl') #for Giacomo
recording_medium = Recording('/Users/giaco/Desktop/ETH/Mobile_Health/DATA/data/example/medium_walk.pkl') #for Giacomo
# recording = Recording('data/example/short_walk.pkl')
# X-axis of the LILYGO accelerometer
ax = recording.data['ax']
ax_medium = recording_medium.data['ax']

print(ax)

print(f"Name of sensor: '{ax.title}'")
print(f"Sample rate: {int(ax.samplerate)} Hz")
print(f"Recording length: {ax.total_time} seconds")
print(f"Timestamp of recording: {ax.raw_timestamps[0][1]}")
print("\nGetting a time series:")
print(" Time           x-Accel")
for x, t in list(zip(ax.timestamps, ax.values))[:20]:
    print(f"{x: .3f}s \t{t:.5f}g")
# Out:
# Trace(title='ax', total_time=11.68, samplerate=201.46, max_update_gap=0.02)
# Name of sensor: 'ax'
# Sample rate: 201 Hz
# Recording length: 11.675 seconds
# Timestamp of recording: 1645184097429
#
# Getting a time series:
#  Time           x-Accel
#  0.000s 	-0.06274g
#  0.005s 	-0.05493g
#  0.010s 	-0.05029g
#  0.015s 	-0.04321g
#  0.020s 	-0.04004g
#  0.025s 	-0.03271g
#  0.030s 	-0.03638g
#  0.035s 	-0.04028g
#  0.040s 	-0.03369g
#  0.045s 	-0.02246g
#  0.050s 	-0.02173g
#  0.055s 	-0.02808g
#  0.060s 	-0.02319g
#  0.065s 	-0.01953g
#  0.070s 	-0.01953g
#  0.074s 	-0.01611g
#  0.079s 	-0.01318g
#  0.084s 	-0.01514g
#  0.089s 	-0.02197g
#  0.094s 	-0.02246g

# %% [markdown]
# # Plotting

# %%
# Display a simple plot
recording.plot(['ax'])
#recording_medium.plot(['ax'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot multiple axes at the same time
# It's also possible to give titles to the y-axis and plots
recording.plot(['ax', 'ay', 'az'], ylabels=['acceleration [g]'], labels=['Acc X', 'Acc Y', 'Acc Z'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot multiple sensors and multiple axes at the same time
recording.plot([['ax', 'ay', 'az'], ['gx', 'gy', 'gz'], ['mx', 'my', 'mz'], ['altitude'], ['speed']], 
             ylabels=['acceleration [g]', 'rot. vel. [deg/s]', 'field strength [µT]', 'altitude [m]', 'speed [m/s]'],
             labels=[['Acc X', 'Acc Y', 'Acc Z'], ['Gyro X', 'Gyro Y', 'Gyro Z'], ['Mag X', 'Mag Y', 'Mag Z'], ['Altitude'], ['Speed']])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# How to Zoom In: use start_s and end_s to specify the time range in seconds
# start_s: start of the range you want to plot (in seconds since the start of the trace)
# end_s: end of the range you want to plot (in seconds since the start of the trace)
recording.plot([['ax', 'ay', 'az'], ['gx', 'gy', 'gz'], ['mx', 'my', 'mz'], ['altitude'], ['speed']], 
             ylabels=['acceleration [g]', 'rot. vel. [deg/s]', 'field strength [µT]', 'altitude [m]', 'speed [m/s]'],
             labels=[['Acc X', 'Acc Y', 'Acc Z'], ['Gyro X', 'Gyro Y', 'Gyro Z'], ['Mag X', 'Mag Y', 'Mag Z'], ['Altitude'], ['Speed']],
               start_s=10, end_s=70)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Display GPS data

# %%
# Recording must contain gps data
assert('latitude' in recording.data and 'longitude' in recording.data)

plot_map_zurich = True

# Visualize the path of the trace
fig, ax = plt.subplots(figsize = (11,6))
ax.scatter(recording.data['longitude'].values, recording.data['latitude'].values, zorder=1, alpha= 0.9, c='b', s=10)
ax.set_title('Visualization of the path')

if plot_map_zurich:
    # Bounding coordinates for map
    BBox = (8.5373,8.5593,
            47.3673, 47.3880)
    # Load map of Zurich
    #ruh_m = plt.imread('/kaggle/input/competitions/26-mham-ex3/mapzurich.png')
    ruh_m = plt.imread('/Users/giaco/Desktop/ETH/Mobile_Health/DATA/mapzurich.png') # for Giacomo
    ax.set_title('GPS visualization in Zurich')
    ax.set_xlim(BBox[0],BBox[1])
    ax.set_ylim(BBox[2],BBox[3])
    ax.imshow(ruh_m, zorder=0, extent = BBox)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Generate computed traces
#
# Small example that adds an accelerometer magnitude trace
#
# <code>Trace.from_modified(cls, title: str, values: np.ndarray, timestamps: np.ndarray, time_offset: float = 0)</code> can be used to save a new or modified trace for the Recording object.
#
# <code>title</code>: Title for this collection of data.<br>
# <code>values</code>: modified values<br>
# <code>timestamps</code>: array of timestamps, one timestamp per value, usually directly taken from the original data<br>
# <code>offset</code>: optional offset in case the "raw_timestamps" should match the original data<br>
#
# Note: This change is only executed locally and not saved to the pkl file. Everytime you reload your dataset, you have to re-execute this steps. Alternatively, you can save a copy of your modified Recording using <code>save_to_pkl</code> (please be careful not to introduce errors in your origninal training set).

# %%
# Trace must contain lilygo accelerometer data
assert('ax' in recording.data and 'ay' in recording.data and 'az' in recording.data)
# And those traces must be of the same length
assert(len(recording.data['ax'].values) == len(recording.data['ay'].values)  and len(recording.data['ax'].values) == len(recording.data['az'].values) )

magn = (recording.data['ax'].values**2 + recording.data['ay'].values**2 + recording.data['az'].values**2)**0.5

recording.data['a_mag'] = Trace.from_modified('Accelerometer magnitude', magn, recording.data['ax'].timestamps, recording.data['ax'].raw_timestamps[0][1])

recording.plot([['ax', 'ay', 'az'], ['a_mag']])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # FYI: How Timestamps Are Handled (You Probably Don't Need This)
#
# Every time the smartphone receives a package via Bluetooth from the LilyGo smartwatch, up to 16 sensor values are stored at once, together with the current timestamp. Therefore, not every sensor reading has a perfectly defined timestamp that is 100% accurate.
#
# Each <code>Trace</code> contains a list of <code>raw_timestamps</code>, which are tuples of the type `(trace index, timestamp)`.
#
# The timestamps are standard Unix timestamps in milliseconds.
#
# For example, the first two entries indicate "The 0th value arrived at 1645184293057, the 16th value at 1645184293144."

# %%
recording.data["ax"].raw_timestamps
# Out:
# [(0, 1645184097429),
#  (16, 1645184097507),
#  (32, 1645184097589),
#  (48, 1645184097631),
#  (64, 1645184097713),
#  (80, 1645184097797),
#  (96, 1645184097880),
#  (112, 1645184097961),
#  (128, 1645184098045),
#  (144, 1645184098125),
#  (160, 1645184098209),
#  (176, 1645184098292),
#  (192, 1645184098374),
#  (208, 1645184098459),
#  (224, 1645184098538),
#  (240, 1645184098620),
#  (256, 1645184098703),
#  (272, 1645184098787),
#  (288, 1645184098871),
#  (304, 1645184098952),
#  (320, 1645184098996),
#  (336, 1645184099076),
#  (352, 1645184099167),
#  (368, 1645184099239),
#  (384, 1645184099321),
#  (400, 1645184099404),
#  (416, 1645184099489),
#  (432, 1645184099570),
#  (448, 1645184099657),
#  (464, 1645184099734),
#  (480, 1645184099817),
#  (496, 1645184099899),
#  (512, 1645184099986),
#  (528, 1645184100065),
#  (544, 1645184100149),
#  (560, 1645184100231),
#  (576, 1645184100312),
#  (592, 1645184100353),
#  (608, 1645184100446),
#  (624, 1645184100520),
#  (640, 1645184100600),
#  (656, 1645184100685),
#  (672, 1645184100767),
#  (688, 1645184100849),
#  (704, 1645184100930),
#  (720, 1645184101013),
#  (736, 1645184101095),
#  (752, 1645184101177),
#  (768, 1645184101260),
#  (784, 1645184101342),
#  (800, 1645184101424),
#  (816, 1645184101508),
#  (832, 1645184101591),
#  (848, 1645184101674),
#  (864, 1645184101714),
#  (880, 1645184101807),
#  (896, 1645184101891),
#  (912, 1645184101964),
#  (928, 1645184102044),
#  (944, 1645184102126),
#  (960, 1645184102212),
#  (976, 1645184102292),
#  (992, 1645184102375),
#  (1008, 1645184102460),
#  (1024, 1645184102540),
#  (1040, 1645184102623),
#  (1056, 1645184102704),
#  (1072, 1645184102792),
#  (1088, 1645184102874),
#  (1104, 1645184102952),
#  (1120, 1645184102993),
#  (1136, 1645184103076),
#  (1152, 1645184103159),
#  (1168, 1645184103241),
#  (1184, 1645184103323),
#  (1200, 1645184103406),
#  (1216, 1645184103490),
#  (1232, 1645184103570),
#  (1248, 1645184103655),
#  (1264, 1645184103735),
#  (1280, 1645184103818),
#  (1296, 1645184103903),
#  (1312, 1645184103984),
#  (1328, 1645184104066),
#  (1344, 1645184104148),
#  (1360, 1645184104231),
#  (1376, 1645184104312),
#  (1392, 1645184104354),
#  (1408, 1645184104437),
#  (1424, 1645184104521),
#  (1440, 1645184104604),
#  (1456, 1645184104687),
#  (1472, 1645184104768),
#  (1488, 1645184104851),
#  (1504, 1645184104932),
#  (1520, 1645184105014),
#  (1536, 1645184105108),
#  (1552, 1645184105184),
#  (1568, 1645184105267),
#  (1584, 1645184105345),
#  (1600, 1645184105427),
#  (1616, 1645184105510),
#  (1632, 1645184105598),
#  (1648, 1645184105675),
#  (1664, 1645184105715),
#  (1680, 1645184105806),
#  (1696, 1645184105883),
#  (1712, 1645184105966),
#  (1728, 1645184106046),
#  (1744, 1645184106139),
#  (1760, 1645184106214),
#  (1776, 1645184106294),
#  (1792, 1645184106377),
#  (1808, 1645184106459),
#  (1824, 1645184106547),
#  (1840, 1645184106623),
#  (1856, 1645184106708),
#  (1872, 1645184106794),
#  (1888, 1645184106885),
#  (1904, 1645184106952),
#  (1920, 1645184107037),
#  (1936, 1645184107077),
#  (1952, 1645184107159),
#  (1968, 1645184107243),
#  (1984, 1645184107324),
#  (2000, 1645184107409),
#  (2016, 1645184107492),
#  (2032, 1645184107573),
#  (2048, 1645184107656),
#  (2064, 1645184107738),
#  (2080, 1645184107822),
#  (2096, 1645184107903),
#  (2112, 1645184107986),
#  (2128, 1645184108069),
#  (2144, 1645184108152),
#  (2160, 1645184108233),
#  (2176, 1645184108314),
#  (2192, 1645184108398),
#  (2208, 1645184108448),
#  (2224, 1645184108524),
#  (2240, 1645184108608),
#  (2256, 1645184108692),
#  (2272, 1645184108771),
#  (2288, 1645184108852),
#  (2304, 1645184108945),
#  (2320, 1645184109019),
#  (2336, 1645184109104)]

# %%
recording.data['ax'].raw_timestamps[-1][1]-recording.data['ax'].raw_timestamps[0][1]
# Out:
# 11675

# %% [markdown]
# The LilyGo uses a FIFO with a constant sampling rate, so it should be a fair assumption, that the delay between two consecutive readings is always the same.
#
# By default the <code>Trace.timestamps</code> array is linearly interpolated between the first and the last timestamp (<code>linspace(0, last_timestamp, num=len(values))</code>)

# %%
# Compare "ideal" interpolated timestamps against actual received timestamps
recording.data['ideal_ts'] = Trace('ideal_ts', 
                                   [recording.data['timestamp'].values[0], recording.data['timestamp'].values[-1]], 
                                   [(0,recording.data['timestamp'].values[0]), 
                                    (len(recording.data['timestamp'].values), recording.data['timestamp'].values[-1])])
recording.plot(['timestamp', 'ideal_ts'], labels=['Received timestamps', 'Interpolated Timestamps'], ylabels=['ms'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
